# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
edata = pd.read_csv('Ecommerce Customers.csv')
edata.head()
# Out:
#                            Email  \
# 0      mstephenson@fernandez.com
# 1              hduke@hotmail.com
# 2               pallen@yahoo.com
# 3        riverarebecca@gmail.com
# 4  mstephens@davidson-herman.com
#
#                                              Address            Avatar  \
# 0       835 Frank Tunnel\nWrightmouth, MI 82180-9605            Violet
# 1     4547 Archer Common\nDiazchester, CA 06566-8576         DarkGreen
# 2  24645 Valerie Unions Suite 582\nCobbborough, D...            Bisque
# 3   1414 David Throughway\nPort Jason, OH 22070-1220       SaddleBrown
# 4  14023 Rodriguez Passage\nPort Jacobville, PR 3...  MediumAquaMarine
#
#    Avg. Session Length  Time on App  Time on Website  Length of Membership  \
# 0            34.497268    12.655651        39.577668              4.082621
# 1            31.926272    11.109461        37.268959              2.664034
# 2            33.000915    11.330278        37.110597              4.104543
# ...

# %%
edata.columns
# Out:
# Index(['Email', 'Address', 'Avatar', 'Avg. Session Length', 'Time on App',
#        'Time on Website', 'Length of Membership', 'Yearly Amount Spent'],
#       dtype='object')

# %%
edata.describe()
# Out:
#        Avg. Session Length  Time on App  Time on Website  \
# count           500.000000   500.000000       500.000000
# mean             33.053194    12.052488        37.060445
# std               0.992563     0.994216         1.010489
# min              29.532429     8.508152        33.913847
# 25%              32.341822    11.388153        36.349257
# 50%              33.082008    11.983231        37.069367
# 75%              33.711985    12.753850        37.716432
# max              36.139662    15.126994        40.005182
#
#        Length of Membership  Yearly Amount Spent
# count            500.000000           500.000000
# mean               3.533462           499.314038
# std                0.999278            79.314782
# min                0.269901           256.670582
# 25%                2.930450           445.038277
# 50%                3.533975           498.887875
# 75%                4.126502           549.313828
# max                6.922689           765.518462

# %%
edata.nunique()
# Out:
# Email                   500
# Address                 500
# Avatar                  138
# Avg. Session Length     500
# Time on App             500
# Time on Website         500
# Length of Membership    500
# Yearly Amount Spent     500
# dtype: int64

# %%
edata.isnull().any()
# Out:
# Email                   False
# Address                 False
# Avatar                  False
# Avg. Session Length     False
# Time on App             False
# Time on Website         False
# Length of Membership    False
# Yearly Amount Spent     False
# dtype: bool

# %%
# اعلي واحد بيصرف في السنه
edata[edata['Yearly Amount Spent'] == edata['Yearly Amount Spent'].max()]
# Out:
#              Email                                           Address  \
# 65  kyang@diaz.org  223 Love Trail Suite 831\nPort Jeffrey, IN 46849
#
#        Avatar  Avg. Session Length  Time on App  Time on Website  \
# 65  OliveDrab            34.374258    15.126994        37.157624
#
#     Length of Membership  Yearly Amount Spent
# 65              5.377594           765.518462

# %%
# متوسط الصرف لكل المستخدمين
edata['Yearly Amount Spent'].mean()
# Out:
# 499.3140382585909

# %%
edata[edata['Time on App'] == edata['Time on App'].max()]
# Out:
#              Email                                           Address  \
# 65  kyang@diaz.org  223 Love Trail Suite 831\nPort Jeffrey, IN 46849
#
#        Avatar  Avg. Session Length  Time on App  Time on Website  \
# 65  OliveDrab            34.374258    15.126994        37.157624
#
#     Length of Membership  Yearly Amount Spent
# 65              5.377594           765.518462

# %%
edata[edata['Time on Website'] == edata['Time on Website'].max()]
# Out:
#                           Email                                       Address  \
# 69  davisrobert@hicks-smith.com  95967 Pitts Burgs\nWest Sarah, MH 27817-5147
#
#      Avatar  Avg. Session Length  Time on App  Time on Website  \
# 69  SkyBlue              32.1791    11.187539        40.005182
#
#     Length of Membership  Yearly Amount Spent
# 69               3.55265           451.575685

# %%
edata.corr()['Yearly Amount Spent'].sort_values(ascending=False)
# Out:
# Yearly Amount Spent     1.000000
# Length of Membership    0.809084
# Time on App             0.499328
# Avg. Session Length     0.355088
# Time on Website        -0.002641
# Name: Yearly Amount Spent, dtype: float64

# %%
edata[edata['Length of Membership'] == edata['Length of Membership'].max()]
# Out:
#                 Email                     Address Avatar  Avg. Session Length  \
# 157  asilva@yahoo.com  USNV Johnson\nFPO AP 19026  Wheat            34.603311
#
#      Time on App  Time on Website  Length of Membership  Yearly Amount Spent
# 157    12.207298        33.913847              6.922689           744.221867

# %%
provides = []

for item in range(0,500):
    provides.append(edata['Email'][item].split('@')[1][:-4])

# %%
edata['mailprovide'] = provides

# %%
edata['mailprovide'].value_counts()
# Out:
# hotmail          87
# gmail            87
# yahoo            76
# johnson           3
# lee               2
#                  ..
# lara-waters       1
# bailey-gordon     1
# day               1
# hale-duncan       1
# richards          1
# Name: mailprovide, Length: 239, dtype: int64

# %%
edata.plot(kind='scatter' , x = 'Time on App' , y='Yearly Amount Spent')

# %%
from pandas.plotting import scatter_matrix
attrs = ['Time on App','Time on Website','Length of Membership','Yearly Amount Spent']
scatter_matrix(edata[attrs], figsize=(12,6))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000026F19E93088>,
# ...
#       dtype=object)

# %%
edata['Email'][1].split('@')[1][:-4]
# Out:
# 'hotmail'

# %%
edata['Time on E']  = edata['Time on App'] + edata['Time on Website']
edata
# Out:
#                              Email  \
# 0        mstephenson@fernandez.com
# 1                hduke@hotmail.com
# 2                 pallen@yahoo.com
# 3          riverarebecca@gmail.com
# 4    mstephens@davidson-herman.com
# ..                             ...
# 495   lewisjessica@craig-evans.com
# 496            katrina56@gmail.com
# 497             dale88@hotmail.com
# 498            cwilson@hotmail.com
# 499      hannahwilson@davidson.com
#
#                                                Address            Avatar  \
# 0         835 Frank Tunnel\nWrightmouth, MI 82180-9605            Violet
# 1       4547 Archer Common\nDiazchester, CA 06566-8576         DarkGreen
# 2    24645 Valerie Unions Suite 582\nCobbborough, D...            Bisque
# 3     1414 David Throughway\nPort Jason, OH 22070-1220       SaddleBrown
# 4    14023 Rodriguez Passage\nPort Jacobville, PR 3...  MediumAquaMarine
# ..                                                 ...               ...
# ...

# %%
edata[edata['Time on E'] == edata['Time on E'].max()]
# Out:
#                   Email                           Address           Avatar  \
# 255  pkline@hotmail.com  PSC 6338, Box 7637\nAPO AA 22066  MediumTurquoise
#
#      Avg. Session Length  Time on App  Time on Website  Length of Membership  \
# 255            33.136655    13.891313        39.220713              2.907095
#
#      Yearly Amount Spent  Time on E
# 255           524.797628  53.112026

# %%
edata.plot(kind='scatter' , x = 'Time on E' , y='Yearly Amount Spent')

# %%
edata['visit'] = edata['Time on E'] / edata['Avg. Session Length']
edata

# %%
# edata[edata['visit'] == edata['visit'].max()]
edata

# %%
# edata.drop('mailprovide' , axis = 1 , inplace = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-146-10330b7eb15d> in <module>
# ----> 1 edata.drop('mailprovide' , axis = 1 , inplace = True)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3995             level=level,
#    3996             inplace=inplace,
# -> 3997             errors=errors,
#    3998         )
#    3999
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3934         for axis, labels in axes.items():
#    3935             if labels is not None:
# -> 3936                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3937
#    3938         if inplace:
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
# ...

# %%
datacopy = edata.copy()

# %%
datacopy['Time E'] = edata['Time on E']

# %%
x =datacopy.drop('Yearly Amount Spent' , axis = 1)
y = datacopy['Yearly Amount Spent']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.8, random_state=42)

# %%
X_train
# Out:
#      Avg. Session Length  Time on App  Length of Membership     Time E
# 212            33.304431    12.378490              3.843849  51.142787
# 295            31.309193    11.947175              3.205530  48.138009
# 457            33.119954    12.953263              3.472021  49.987542
# 251            32.728521    10.131712              3.287702  44.977325
# 488            35.630854    12.125402              4.019051  50.313166
# ..                   ...          ...                   ...        ...
# 106            32.291756    12.190474              3.781823  48.342936
# 270            34.006489    12.956277              3.275734  51.611371
# 348            31.812483    10.886921              3.128639  45.784749
# 435            32.259973    14.132893              3.762070  51.156373
# 102            32.425697    11.448902              2.586968  49.029092
#
# [100 rows x 4 columns]

# %%
from sklearn.linear_model import LinearRegression
linear= LinearRegression()

# %%
linear.fit(X_train , y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
linear.score(X_train , y_train)
# Out:
# 0.986564439502981
